# %%
from api_key import *  #key=

# %%
import urllib2
import json

# %%
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=restaurants+in+Sydney"
url += '&key=' + key
response = urllib2.urlopen(url)
json.load(response)
# Out:
# {u'html_attributions': [],
#  u'next_page_token': u'CoQC_gAAALir3DXuOEcqK25wjriX4XGDAWapa5J0LhTcutaEuoZyg1o1jzMOzq8mzAJnONErnCuShnDLVGKRHQCAcwfrKW1k58XbZq3okrZjT-gqMIJK03ekBRWv6ejqfcJwpfYcZ8KFc9SNoCYuAmt7W754gBJnLheGxCevwqWbhJQpuB_sha4SgaN5WhDV7FpEkFvnij32a7-VR57XpJgjR34AgCm-wphBetK1pxNGdfxSdGk-fb-zR_0fbUJi9TbOAgJyR73Ny5nciG6_NoMXwYmLgvNdpc3yYfO6sGXwFX1ar7r4c-BcDnGTGNcYh3gmxn6p-3QNTIqjTLR63M31qMG6eUQSENH_NROrS10Bs9ZS1AC4fMgaFIYSKZp0k1fa9OfJe8Oa0p5SbBCc',
#  u'results': [{u'formatted_address': u'529 Kent St, Sydney NSW 2000, Australia',
#    u'geometry': {u'location': {u'lat': -33.875154, u'lng': 151.204976},
#     u'viewport': {u'northeast': {u'lat': -33.8737485697085,
#       u'lng': 151.2065211302915},
#      u'southwest': {u'lat': -33.8764465302915, u'lng': 151.2038231697085}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'827f1ac561d72ec25897df088199315f7cbbc8ed',
#    u'name': u"Tetsuya's Restaurant",
#    u'opening_hours': {u'open_now': False, u'weekday_text': []},
#    u'photos': [{u'height': 1365,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/105395521304326551280/photos">Tetsuya&#39;s Restaurant</a>'],
#      u'photo_reference': u'CmRaAAAADj8XQ5tRAN6myDnWUySqpgppZ1d_c_6oXJGYI-Kly1q2A-hLQMC4DYwkPJZfZvK62qnubFDHOCFZx4LFDg7xK4fUN4R8Nh8EJT-gFT2FG2ILTGcau3hUeDHsj-m46KumEhDSo5wXY13Mbdu_qIm81kLWGhRpzcMrioKe4rm2BGGTeYuCseHJfQ',
#      u'width': 2048}],
#    u'place_id': u'ChIJxXSgfDyuEmsR3X5VXGjBkFg',
#    u'price_level': 4,
#    u'rating': 4.5,
#    u'reference': u'CmRRAAAA5Hh0_6IRYJkvfFi_chwV49JdnVwsnFTlgFMD4dqTXB4U4rke1OMxQpLJCONQXD1rH8rPzBQJ1DNfzF1DY0eQ8aM1SMOp04Cu-IGApFYfZEmO6NPqdF5LssJzABWmZdhnEhAR_jqKKj5hCo_HgNPc1YQSGhQRSXRagHZOQd2YVLWdkwQz0OmONw',
#    u'types': [u'restaurant', u'food', u'point_of_interest', u'establishment']},
#   {u'formatted_address': u'1 Macquarie St, Sydney NSW 2000, Australia',
#    u'geometry': {u'location': {u'lat': -33.8590989, u'lng': 151.21335},
#     u'viewport': {u'northeast': {u'lat': -33.8577421697085,
#       u'lng': 151.2147763302915},
#      u'southwest': {u'lat': -33.8604401302915, u'lng': 151.2120783697085}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'351c1e447399e05b27ace20708d9165a4047804f',
#    u'name': u'ARIA Restaurant',
#    u'opening_hours': {u'open_now': False, u'weekday_text': []},
#    u'photos': [{u'height': 2988,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/114907985204651821284/photos">Samuel chui</a>'],
#      u'photo_reference': u'CmRaAAAAEwWpERwxdPVEujGwp6jXcE5egXxaRrTxZp7o3jaIxZHCiF6UkLJBq_-uproJ3zANXG9rEDu3wiV6jH3oGOLlcEoaCE7yz8K3WEhqJx_0OzbfAFcGXHy4dd9LHl9sKiGkEhCgjhNjIjq5euN1tua1YRLdGhSKqXmmb-Dst_blxegUbBd7YAtNnw',
#      u'width': 5312}],
#    u'place_id': u'ChIJdxxU1WeuEmsR11c4fswX-Io',
#    u'price_level': 4,
#    u'rating': 4.2,
#    u'reference': u'CmRSAAAAtRgVlySqM2h4waBvHyB1uwqVXmmrchmp9TkrPRUtxkaSpFHNtoZB1QUBwAjHWZOC_zk8W4b5h4mKzfix55aiLW_u99R7FYv-0m0o_spjvh5ydxNBHn0Bg3W5AFiP-CfPEhCz3SioRh0hxKFqrulcEEjaGhRfGDlgn6XU2O8TsUch3LGlQYzjOQ',
#    u'types': [u'restaurant', u'food', u'point_of_interest', u'establishment']},
#   {u'formatted_address': u'3 Bridge St, Sydney NSW 2000, Australia',
#    u'geometry': {u'location': {u'lat': -33.8640681, u'lng': 151.2080514},
#     u'viewport': {u'northeast': {u'lat': -33.8627032197085,
#       u'lng': 151.2093821302915},
#      u'southwest': {u'lat': -33.8654011802915, u'lng': 151.2066841697085}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'7cc9df1247348a54523b0cb74bff6636dd447daf',
#    u'name': u'Mr. Wong',
#    u'opening_hours': {u'open_now': False, u'weekday_text': []},
#    u'photos': [{u'height': 480,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/113719639442868633401/photos">Ashley Hughes</a>'],
#      u'photo_reference': u'CmRaAAAA-SfmqWNf6YIwkVlukMUlJPfTZiFgJ8Qjl3tXscKEMB_eVzb5kzUVesrCvtoeZgwbTREfGuAnxHXgZ0_CJDxsemDYaZjbaGiYHr-elfzhb84bD30sCGb5-82EH3CKv38WEhDb5RzZYmidS2J61widpjNoGhSAZ06v3LTHh_UUG663VmKicMCRAw',
#      u'width': 720}],
#    u'place_id': u'ChIJT2CGg0GuEmsRYLRNCFoOvv4',
#    u'rating': 4.2,
#    u'reference': u'CmRSAAAAcRssnMmVBJLsMou6tcBmOlE-KY9jZ9ylX85nMVGSCa9-2I-U7I_Q3l22N46_snDp99d7ETemskwBqtBLcbpSgI3T4Qc6SPOaBOqBVzsyNZRvnp7JIVEr6ohrHBOGasyqEhBdypDHL49gWjxKh_oyUdUeGhRyxIT9BH8eJzTJCNFxU1Hvm9qkRA',
#    u'types': [u'cafe',
#     u'bar',
#     u'restaurant',
#     u'food',
#     u'point_of_interest',
#     u'establishment']},
#   {u'formatted_address': u'1, Establishment/252 George St, Sydney NSW 2000, Australia',
#    u'geometry': {u'location': {u'lat': -33.8639755, u'lng': 151.207602},
#     u'viewport': {u'northeast': {u'lat': -33.8626213197085,
#       u'lng': 151.2088625302915},
#      u'southwest': {u'lat': -33.86531928029149, u'lng': 151.2061645697085}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'741a65fc088d15941b6c14e420e650d1435484af',
#    u'name': u'est.',
#    u'opening_hours': {u'open_now': False, u'weekday_text': []},
#    u'photos': [{u'height': 3648,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/106438061919787359752/photos">Andrew Stuart</a>'],
#      u'photo_reference': u'CmRaAAAAUtHWfN0XlA_MxhsMY3fG8Mw7EiklMQO_kfi7TvCfojfBbftG267lKC9ahO9nN-hwoG9LYT44YXXMGXlaov7qfGoYz7Ryq5Fvy-2TUJlPV2MtW0TwtvIPo-_-fGBsZOC0EhAsCNrQs7PRWByZ2tRIHuhdGhTssvKqn_uDPqG5eq8oB2aoJ3AF_A',
#      u'width': 6960}],
#    u'place_id': u'ChIJcQiKnEGuEmsR5hNrm6Kee9M',
#    u'price_level': 4,
#    u'rating': 4.4,
#    u'reference': u'CmRSAAAA2n8MFvLh8PUbmNbPBbHXq71IPm6HcFcRBTPEKaH1X9VJpz0i-G_mS7yu3CqXmjaU_CdBYsjjkMWf4W_3O5zf3HKCXx-hgdxzrSEFyER-fbfUOaCCa89X4vU5mxrY8rFyEhAPjIDKbo5Iia_tDsxAqpidGhSyqR0OR9LJlnkZpqkymrmsVteaSQ',
#    u'types': [u'restaurant',
#     u'bar',
#     u'food',
#     u'point_of_interest',
#     u'establishment']},
#   {u'formatted_address': u'11 Hickson Rd, Sydney NSW 2000, Australia',
#    u'geometry': {u'location': {u'lat': -33.8541648, u'lng': 151.2081089},
#     u'viewport': {u'northeast': {u'lat': -33.8528620197085,
#       u'lng': 151.2095637302915},
#      u'southwest': {u'lat': -33.8555599802915, u'lng': 151.2068657697085}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'60d688823714ebcc61393e7b2b92c287e994c03a',
#    u'name': u'The Gantry Restaurant & Bar',
#    u'opening_hours': {u'open_now': False, u'weekday_text': []},
#    u'photos': [{u'height': 1536,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/101132328843891141125/photos">The Gantry Restaurant &amp; Bar</a>'],
#      u'photo_reference': u'CmRaAAAAxl3iFFA4f_2PLp2Ec36HCkY-dnjWrTN7ZlC6G5EWb8HA2NxRY8EExy8czQk8I1A_fysPPVx_53oQvW-gUFhELbCcxn_ltgtBP4aQhYuRDcKjlhS7suy3Tl4yOHxJwJv1EhDvMGhkcVXkM7Ar28q7kZltGhS_K9a43Ii1bjE7fVhir-zPHHoQDA',
#      u'width': 2048}],
#    u'place_id': u'ChIJ-choyF2uEmsRIosIxEjVxnA',
#    u'price_level': 3,
#    u'rating': 4.3,
#    u'reference': u'CmRRAAAAea20fk7SQYfw1YXxMdPBmCZFlIft-v9OILZpeUplBoLFwSnRtrRsu3VEDTJFHd5hyzY9FJaSgSun1z333N9Zzl6zrrNDnPJjupog1BdwRve_WLupORNEz1wobD_D2qCXEhDa39ShGOSlG6QmLEjnYzpdGhSiYpNMReU_Q8jiaK54IElXMKPw8w',
#    u'types': [u'restaurant',
#     u'bar',
#     u'food',
#     u'point_of_interest',
#     u'establishment']},
#   {u'formatted_address': u'39 Lime St, Sydney NSW 2000, Australia',
#    u'geometry': {u'location': {u'lat': -33.867806, u'lng': 151.20172},
#     u'viewport': {u'northeast': {u'lat': -33.8664997697085,
#       u'lng': 151.2031814802915},
#      u'southwest': {u'lat': -33.8691977302915, u'lng': 151.2004835197085}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'bce0dd3ab6090cd86021efb6eef923fa59b8f417',
#    u'name': u'The Malaya',
#    u'opening_hours': {u'open_now': False, u'weekday_text': []},
#    u'photos': [{u'height': 885,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/112797482079521405927/photos">The Malaya</a>'],
#      u'photo_reference': u'CmRaAAAAsDM-76oMajktgLCpR3ZWZZOZYRIee5LLLMzlxdyYO3U1rpNZcG6BzdxqrvxCeyB9rn1Ef8P4GTfEAb9uMNDRhut9CobmbVWb8Qdivy_2mlGu7v3S4C3RA8r0QsWECh0vEhC52xtDlrpX2XjCMz2lg64BGhTvhYqbzAl4IrzpHVxAVg-h-RpuVg',
#      u'width': 884}],
#    u'place_id': u'ChIJ4U8HhjiuEmsRyevJVTxWbFo',
#    u'price_level': 2,
#    u'rating': 4.2,
#    u'reference': u'CmRRAAAAt7Gkwet6zT3JqZJhKaE7xiHna2xQ_U4WgjG1A8o77R72tymGK-0CbtyHqceO29R4TfTWIbMnDOb5K9ony20fLlYmtybpGp77xw7u9vlYY3EYU6vNSIxAd7zLQ7r7XReeEhB52cd1UV7zffDIVwYmFOeRGhSMmxhf3PeNiJpDiTxDOLqKcPlI8w',
#    u'types': [u'restaurant', u'food', u'point_of_interest', u'establishment']},
#   {u'formatted_address': u'Bennelong Point, Sydney Opera House, Sydney NSW 2000, Australia',
#    u'geometry': {u'location': {u'lat': -33.85756, u'lng': 151.214688},
#     u'viewport': {u'northeast': {u'lat': -33.8562110197085,
#       u'lng': 151.2160369802915},
#      u'southwest': {u'lat': -33.8589089802915, u'lng': 151.2133390197085}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png',
#    u'id': u'ef110129118aa8e9baa5832d3b5d074e9eae05ed',
#    u'name': u'Bennelong Restaurant and Bar',
#    u'opening_hours': {u'open_now': False, u'weekday_text': []},
#    u'photos': [{u'height': 1141,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/112350297531282885227/photos">Bennelong Restaurant and Bar</a>'],
#      u'photo_reference': u'CmRaAAAA-4K7599cY-1UPsidu5eUyMwj0o0rGHlpAdyF54g9bIg104FcE12I-MJ6wUoco6844QQFXLoD8uIbZ9Xgf-_xIDI9pC0MqNLrFByy-nJbVRxpo57dA60n39JYTaJW1wzsEhDkZd5XOJePU0LIMCK9f2IrGhTmGuNcoA0la4RCevzZs-jwtr4Smg',
#      u'width': 1599}],
#    u'place_id': u'ChIJQcmNYGauEmsR84D5HAJJUhw',
#    u'rating': 4.1,
#    u'reference': u'CmRRAAAAxxSgrWJAcEeXdLE6_tl34W0Urnu1UffJ-l7mXboGG2e-1DtlB7mLDJXd4Yw4bvQEBjnyaEKcACiUmivNH9M6nkO8FQrn7dND_pjVZ_yMEIp9gnuyaDgm4tRt2sWGhQSsEhDCVzKoOui71JfLk4iUom_dGhRIeaLQFEA36Ythq-dIHborR1LMwA',
#    u'types': [u'bar',
#     u'restaurant',
#     u'food',
#     u'point_of_interest',
#     u'establishment']},
#   {u'formatted_address': u'209 Clarence St, Sydney NSW 2000, Australia',
#    u'geometry': {u'location': {u'lat': -33.8699529, u'lng': 151.2053065},
#     u'viewport': {u'northeast': {u'lat': -33.8686000697085,
#       u'lng': 151.2067060802915},
#      u'southwest': {u'lat': -33.8712980302915, u'lng': 151.2040081197085}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'12df5bd80d9838decd54056e02c7b0f188e1faa2',
#    u'name': u'Fortune Village Chinese Restaurant',
#    u'opening_hours': {u'open_now': False, u'weekday_text': []},
#    u'photos': [{u'height': 2448,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/113338699552201420673/photos">eatwith myfoodsafari</a>'],
#      u'photo_reference': u'CmRaAAAA6T6FmkFr67Uffuikh9kX06kp_ultB9onCiNN9LES0J8AtbdUUYKmb8cPVn7xkMFTeWBrwTrV3NydGRRz-xdhtIa6ntPaaXAQZQWO_EmJOmgCBSBuGHne5BoQfRpGjhHnEhA1iMg-jIJMO2aXn6YmVeIgGhTDbxrQ61atEwQB1e9GLwfkm4J3KQ',
#      u'width': 3264}],
#    u'place_id': u'ChIJ6SyQGT-uEmsRdQsqqRXMO40',
#    u'rating': 4.3,
#    u'reference': u'CmRSAAAAPAlskhCtG8oCjxcHRSA4Nqt1LlIgsMZaOWFxleURDBcG8aShiM8Hjt3S7iv-nz1gVbo7VUGYweBG_K-S00pZi_GRNQjBOX61v_UGz9WtvwVp5pX-6XBq3p6wSvOztQadEhA6Kau3cTD4AEHE0uomQoYNGhR6UrhVOWih0huh-n05014GtRPBtA',
#    u'types': [u'restaurant', u'food', u'point_of_interest', u'establishment']},
#   {u'formatted_address': u"27 O'Connell St, Sydney NSW 2000, Australia",
#    u'geometry': {u'location': {u'lat': -33.86560290000001,
#      u'lng': 151.2088283},
#     u'viewport': {u'northeast': {u'lat': -33.8641896697085,
#       u'lng': 151.2103488802915},
#      u'southwest': {u'lat': -33.8668876302915, u'lng': 151.2076509197085}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'a71f631fb3d71b90a80fdd04c3b14c50bb308b5b',
#    u'name': u'Bentley Restaurant + Bar',
#    u'opening_hours': {u'open_now': False, u'weekday_text': []},
#    u'photos': [{u'height': 3024,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/106548518015723611844/photos">Menura De Silva</a>'],
#      u'photo_reference': u'CmRaAAAAszal_0j91HvMXgdWAc10GmHj4ycUFhwWILt-kRBBQZbcaTrZWJVVNZuco0wY1XWOpJ9PRSB5WmsCFrsGoiHMXEL6up8V8ZYsD2S7yC-V6CDGjUFn09cbI94ivv5ycdCyEhB_QZmcF8hn5Avm5UomZPOFGhRa6msKOuFi5d-buEnf38mVxA05Og',
#      u'width': 4032}],
#    u'place_id': u'ChIJybJExkGuEmsRmpbxj1gH_-U',
#    u'rating': 4.1,
#    u'reference': u'CmRSAAAA_oHz0XHJU5HXKz6kZrUgmh-qO04PRSvVDsbj4x1Dw9opJkoKqmTGbSda5yTe8xadHLD_bcCh3nof-RfKUFO38G-t6dk7PmwNuzSHgwM3mqL5eFFPQOS8ZYu8AYgwr1GNEhD6PyZY6c97zRWAD_TDiatuGhQjjEc1hAxxtQquZYXS7ZHYesVT-g',
#    u'types': [u'bar',
#     u'restaurant',
#     u'food',
#     u'point_of_interest',
#     u'establishment']},
#   {u'formatted_address': u'66 Hunter St, Sydney NSW 2000, Australia',
#    u'geometry': {u'location': {u'lat': -33.86615599999999, u'lng': 151.210296},
#     u'viewport': {u'northeast': {u'lat': -33.8647114697085,
#       u'lng': 151.2115562302915},
#      u'southwest': {u'lat': -33.8674094302915, u'lng': 151.2088582697085}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'9ea0b69b32f49a77528b26a5489c044d570ab477',
#    u'name': u'Rockpool Bar & Grill',
#    u'opening_hours': {u'open_now': False, u'weekday_text': []},
#    u'photos': [{u'height': 1179,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/109362165485185675922/photos">Rockpool Bar &amp; Grill</a>'],
#      u'photo_reference': u'CmRaAAAASS5q1o6QE5MUV96He_TwxOhJlaq7ejRV5IvY6NViInvm9y74rkmRDfYyTxihlY6sDPWUxaRKCFnP0pwblOQJfA_vF7nhlJJIU48Y4WMWxgrM-2h-JmJb_AnkNNDC_0voEhA_EQQOOmFDQQs8WzeMMBDjGhSR5kju-3JsN74u17fwu8ZrOgdZ5Q',
#      u'width': 1772}],
#    u'place_id': u'ChIJV8rt1UGuEmsRf1fObMkd93M',
#    u'price_level': 4,
#    u'rating': 4.4,
#    u'reference': u'CmRRAAAAITSgNoctaZpKsvVsvGtIixaNDUnIqB-A62oeDvppQn-D4GBaRGK-C9_23Ng-V-GqdFk2OsiJrPRTlpmQHY8Bu_kY-PaLL-vDVoP3imYnnRTZMKXXkfB2ow27EN5M1_O5EhAp0vZqEPDosM7N1_90VXqnGhQs4moSeP7BWVBvNYymNsWSQP9rhw',
#    u'types': [u'bar',
#     u'restaurant',
#     u'food',
#     u'point_of_interest',
#     u'establishment']},
#   {u'formatted_address': u'36, Shangri-La Hotel, 176 Cumberland St, Sydney NSW 2000, Australia',
#    u'geometry': {u'location': {u'lat': -33.8611745, u'lng': 151.2065374},
#     u'viewport': {u'northeast': {u'lat': -33.85977786970849,
#       u'lng': 151.2077307802915},
#      u'southwest': {u'lat': -33.86247583029149, u'lng': 151.2050328197085}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'5c2cef250d42f0ff1f642b51f8477a8bba23abbe',
#    u'name': u'Altitude Restaurant',
#    u'opening_hours': {u'open_now': False, u'weekday_text': []},
#    u'photos': [{u'height': 1280,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/106155344778912457393/photos">IS L</a>'],
#      u'photo_reference': u'CmRaAAAA9E4lWwdC9KJsTnpWtwBGfEg5GEK8QvsF5Lus9dwVJc5OP0YfkCs7iRbdN-n5mqaGTdJEE_L1mNkpwvu1_f7Jdtkj6Qbs6hT550_jac0Oe_GTIUijD85ba9GpRm_VEDYbEhAxwRQ5DAzhdToM4PbLXLgLGhRW9TP58MTtg9mkeEfrv9-orJXRPQ',
#      u'width': 1920}],
#    u'place_id': u'ChIJsyWauUOuEmsR-_JBt78Eo-Q',
#    u'price_level': 3,
#    u'rating': 3.4,
#    u'reference': u'CmRSAAAA0xcsODhaz3rM6Lh-tgjvoav3oJhl3F38emuTKCgeJ5ql6HzP5XaunqX3EzMBjYaXYH8PVs7chRNgI9heFzdA370FwooRm36dITBSvLp3gqmUe23Ls7fQU83qUiXobk4jEhBqWOR7wwgwz_vZNOlSeLQXGhQds9HSdOZGuB48MndoI93vSoIi4A',
#    u'types': [u'restaurant', u'food', u'point_of_interest', u'establishment']},
#   {u'formatted_address': u'2 Market St, Sydney NSW 2000, Australia',
#    u'geometry': {u'location': {u'lat': -33.8707713, u'lng': 151.2047063},
#     u'viewport': {u'northeast': {u'lat': -33.8695183197085,
#       u'lng': 151.2060530802915},
#      u'southwest': {u'lat': -33.8722162802915, u'lng': 151.2033551197085}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'476ffd65831c04351bd8110a1a3649467eebf3b0',
#    u'name': u'Medusa Greek Taverna',
#    u'opening_hours': {u'open_now': False, u'weekday_text': []},
#    u'photos': [{u'height': 3024,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/103531669246779428740/photos">Satoshi Kikuchi</a>'],
#      u'photo_reference': u'CmRaAAAAgNvdvFH_SySZIj7Mc0pjTUCLaDHtCL_N-m-2S3DDy6L5N3sUFQD7zs8khSYGrGvNOLeWFIkRDs2uzKSKUq3UyV8lfZjhf86r_nuWScv_fvpaQNP0utZC_0ewoNwTEP-oEhAJXUHvHE2MPC5A2H_NBrn7GhQiDRjNTbVGkCb0EqLZ7P2vk83QiA',
#      u'width': 4032}],
#    u'place_id': u'ChIJmVBj0j6uEmsRlpDNlLL00vU',
#    u'price_level': 2,
#    u'rating': 4.4,
#    u'reference': u'CmRSAAAAjRUOzyDn-y1Zi0c_FciPvoP8m86_56zQN_4W9G5juB0TknazIqVh2VcS1kMpPFq2WbJkrptYlx28VW9UZ8RAQFbxKiLqMQBNcAGkXPzM1yBv0NxzDsllo-D-PI0fn2n9EhDw0hDkAR03urXOV73bRr9DGhQUdog2xRAkmFfvCsuLiQQNiQdB4Q',
#    u'types': [u'restaurant', u'food', u'point_of_interest', u'establishment']},
#   {u'formatted_address': u'47, Australia Square, 264 George St, Sydney NSW 2000, Australia',
#    u'geometry': {u'location': {u'lat': -33.864927, u'lng': 151.207805},
#     u'viewport': {u'northeast': {u'lat': -33.86357801970851,
#       u'lng': 151.2091539802915},
#      u'southwest': {u'lat': -33.8662759802915, u'lng': 151.2064560197085}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'bfc2daa5afd072b2eca10495ac49ec60a3b4832a',
#    u'name': u'O Bar and Dining',
#    u'opening_hours': {u'open_now': False, u'weekday_text': []},
#    u'photos': [{u'height': 1367,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/103649992316188820216/photos">O Bar and Dining</a>'],
#      u'photo_reference': u'CmRaAAAAzN4ilggomZcRqnDzjzaaAE-NNghSkAYlD35kWpxoNudRiVv4c61S7ZCDSs3i0QMFq1mkZM_BaTfSh-y7n0iNgfIUT_6Zy07TSpvljpfwYLTJdAEU2m0b_ybbchvhxZZEEhDnFCQ7L8lf_uz12AxETcAOGhS4TsHwTzVtTgn7RVNoUZb5a4Y4oQ',
#      u'width': 2048}],
#    u'place_id': u'ChIJnzttoEGuEmsRjBEqGkOTGG8',
#    u'price_level': 3,
#    u'rating': 4.3,
#    u'reference': u'CmRRAAAAybBsBojjUl1n0Iro6BMdXBogovSHQAyts9XiCWkyywwUfxUxmlLDKtKIQRDD1kPPgq-6SYiZKcgu7EO09Sir-Ut8vZuYylow5s1TYue6vg2zlK6bbkETx7u-EWj-XwUIEhCPC3JzoNmX820s9RKoPweeGhSVkW41mDimX6YGHMnxTkRlpF1b4A',
#    u'types': [u'restaurant',
#     u'bar',
#     u'food',
#     u'point_of_interest',
#     u'establishment']},
#   {u'formatted_address': u'11 Bridge St, Sydney NSW 2000, Australia',
#    u'geometry': {u'location': {u'lat': -33.8639105, u'lng': 151.2080494},
#     u'viewport': {u'northeast': {u'lat': -33.8624341197085,
#       u'lng': 151.2093852802915},
#      u'southwest': {u'lat': -33.8651320802915, u'lng': 151.2066873197085}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'd24e5fc0d30d142372bda8f3db7bcad1ecdae42f',
#    u'name': u'Jade Temple',
#    u'opening_hours': {u'open_now': False, u'weekday_text': []},
#    u'photos': [{u'height': 3036,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/104639775997587347912/photos">Warren Daley</a>'],
#      u'photo_reference': u'CmRaAAAAtUsh3Sh6zySRKvSwJeTJpZiCKRAn1F6AkbarIMesp6zin5y-lmfJungmY3JtD8sGhfqs-qqF2a3nWZpxKdEIGveEqikhqAWs4-P1XzfVjDm8WjsALOXKebSi6KV7Sj40EhBe9bx1sY9iNirvQ7_AwHbrGhSZOZ9j_fKgMkd_V9vvySdqs10TAQ',
#      u'width': 4048}],
#    u'place_id': u'ChIJN1ha6kKuEmsRO272YpqQOK0',
#    u'price_level': 4,
#    u'rating': 4,
#    u'reference': u'CmRSAAAANvCNTLRemcUorpxn2NK4l7OBKoPrKwYOkAWTELJg68R-bV3CjuOdjbJEaE2Mv42PM8SMzzs1VBOFPD61xvbTRp3Y3aBvXEqPD4Y1AiXnaaVA6Nq0hrVMe88LyGpTHQ18EhCFvt0sSqFySKd5IUSBr2m4GhSO7YG08Av4FUkeJ7DYQVAlPBMMpw',
#    u'types': [u'restaurant', u'food', u'point_of_interest', u'establishment']},
#   {u'formatted_address': u'393-399 Sussex St, Sydney NSW 2000, Australia',
#    u'geometry': {u'location': {u'lat': -33.8779993, u'lng': 151.2045295},
#     u'viewport': {u'northeast': {u'lat': -33.8765938197085,
#       u'lng': 151.2059759302915},
#      u'southwest': {u'lat': -33.8792917802915, u'lng': 151.2032779697085}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'e51026cd2814f600e8789a61cbdf242de32df9be',
#    u'name': u'Golden Century Seafood Restaurant',
#    u'opening_hours': {u'open_now': False, u'weekday_text': []},
#    u'photos': [{u'height': 2268,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/105125173569530675504/photos">Evon Soh</a>'],
#      u'photo_reference': u'CmRaAAAAGsY-L7Pxge1Vkc9L7HNrW3HBBwgV40cKVb1L7qoA-R-giryoWox2MHtgjrM4pwqq0eyl7VFZVKCquRXi197oismlL6DDcK0T2HTUA0hUEsxLhm6zdAVaHOLcXQm4GHxnEhCpABcL2gwkKBMh9REN6kxrGhR2dluuQuBJPfD1kULcgrY5vVOwnA',
#      u'width': 4032}],
#    u'place_id': u'ChIJWTGFVSOuEmsRW654ax8Zjzg',
#    u'price_level': 2,
#    u'rating': 3.8,
#    u'reference': u'CmRRAAAAGZVeTfXYY5k-WUeh9K1GTKvMsi_fLuP37mQ_wd97JRoKyQhOsIEngb5FnnRwJmPnkxcqsx8NjDoJoSjrvCGVfkIBSIRIQxMw-0NHb4b7h2XINkQ5uha3PZctuDcD3rt7EhBYKH8_G_ICChlkGFEDA4ywGhTyHrUcDyX15lcdd3K7fXLr-7no2Q',
#    u'types': [u'restaurant', u'food', u'point_of_interest', u'establishment']},
#   {u'formatted_address': u'15 Goulburn St, Sydney NSW 2000, Australia',
#    u'geometry': {u'location': {u'lat': -33.8777061, u'lng': 151.2041863},
#     u'viewport': {u'northeast': {u'lat': -33.8763086697085,
#       u'lng': 151.2055462302915},
#      u'southwest': {u'lat': -33.8790066302915, u'lng': 151.2028482697085}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'3131064b44977b55eb143141a179c5ed2c5afe04',
#    u'name': u'Mamak',
#    u'opening_hours': {u'open_now': False, u'weekday_text': []},
#    u'photos': [{u'height': 2448,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/102728638357364417283/photos">Elizabeth Munro-Ginn</a>'],
#      u'photo_reference': u'CmRaAAAAq7f7R4Bf7snMnF8SAoSCala2YJBcX_gnP1eV5saJMIXyq7ww3Ys-w3i9xF0XMgK6MJpe5ahDxnDDvDIlsec-EWkzNen_gdNpOymIT9l1OzzELl6aS4h7S26J7wJpIljHEhBG3E7uYeylxP9DZbcmoAiqGhSdggejuyszGXyD9th7mOVY50qiDw',
#      u'width': 3264}],
#    u'place_id': u'ChIJ0b8dqySuEmsRjyQejupL3KA',
#    u'price_level': 1,
#    u'rating': 4.1,
#    u'reference': u'CmRSAAAA2yBbjUuhBej1P2GhWUT9V-otRZuXYX0DtRIgqVZ6nNlgtrFuz5CnzYAndEqxGsFILvrWN03I7H3nTCY6Ld97dIJtTyCvlMA4CsF8zvNaOHEulSeKWWJtKu0fWexleH5SEhBL1qdO_EA-wmm_Nz20raVcGhTskJMvjC-vTXRJJ3c2-uzuBnz8KA',
#    u'types': [u'restaurant', u'food', u'point_of_interest', u'establishment']},
#   {u'formatted_address': u'29 Kent St, Sydney NSW 2000, Australia',
#    u'geometry': {u'location': {u'lat': -33.85868749999999, u'lng': 151.203488},
#     u'viewport': {u'northeast': {u'lat': -33.8573750197085,
#       u'lng': 151.2048474802915},
#      u'southwest': {u'lat': -33.8600729802915, u'lng': 151.2021495197085}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'f038230a12b5176b34555a8be2c0ff66e05c46b8',
#    u'name': u'Fish at the Rocks',
#    u'opening_hours': {u'open_now': False, u'weekday_text': []},
#    u'photos': [{u'height': 2988,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/114426310906773755655/photos">Robert Hunt II</a>'],
#      u'photo_reference': u'CmRaAAAALzzNtsuOcBabc0A-NNHm0WuOLCelHHkkTh_anAmo5VD_pAzjAKL-J1-oN3uFns561JeJgbjjUmk1RswySv1nmn7qCu93c7i7w9jqaW0F_8XVI9Z972VJQAYEtTi7yRLcEhAe_8fqMEAkEpIJFXaei7s_GhSbZIvuA-8Dw9sU5j1PBPb79aF92Q',
#      u'width': 5312}],
#    u'place_id': u'ChIJzThEkUSuEmsRvGm7CeJ-9V4',
#    u'price_level': 3,
#    u'rating': 4.2,
#    u'reference': u'CmRRAAAA09jyP4kyWxOIDsTzL8uLGxMsilYBCc-UqpvDtDIYMC17FM8zaH1ncUYKdFoahEgS9Vf9F_37eVj6Xcde90zoqcN3DOIWcbbp85K3lAiDUl1Ndn3FEJrXTQb-8J-s88XGEhAnNLwOiXNk6QJ5_lKZ2zMgGhT7ck7aC3LE8Nc_MPIqcdTEJ0mf3Q',
#    u'types': [u'restaurant', u'food', u'point_of_interest', u'establishment']},
#   {u'formatted_address': u'The Quay Building, 2 Phillip St, Sydney NSW 2000, Australia',
#    u'geometry': {u'location': {u'lat': -33.8617206, u'lng': 151.2123699},
#     u'viewport': {u'northeast': {u'lat': -33.8603937197085,
#       u'lng': 151.2135832302915},
#      u'southwest': {u'lat': -33.8630916802915, u'lng': 151.2108852697085}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'5226531784f9676217c7c2705055318740ab24d6',
#    u'name': u'The Spice Room',
#    u'opening_hours': {u'open_now': False, u'weekday_text': []},
#    u'photos': [{u'height': 3024,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/103262087127569529029/photos">Neil Roberts</a>'],
#      u'photo_reference': u'CmRaAAAAJH9a_9aFWH7u_BE_kCggjNHFcNZubFxAVRKDuMLwi6Qi4ECF-9CBBF3Vs-EZ7RHR2iJTHA1P8TWRz7OEGJb0L5aRvoFlc1pPjRMijLrv3gxsPR_HvhrHDJe_yaA4U44nEhBhcnRlLgHvj5kg0aJfMggkGhQsw9_1o5Zc8wWahUzM2W1emOkm2A',
#      u'width': 4032}],
#    u'place_id': u'ChIJE18nTWiuEmsRUz-zCmu8p8U',
#    u'price_level': 1,
#    u'rating': 3.9,
#    u'reference': u'CmRSAAAATzUxP_N9dHlvMlo9h_n56ORiewVtAsnL44zETxGCLCAdD2nl7By-ss32BfEGZeqjeR7EFbzRDGwXVkKIhAH_WLEKTZvF1K_FcZ3J4af4n5ovtyaqg_-rdCNt522LlGcVEhCGSPjunOM1okNKdspLN1lZGhSO7JRWFZo8b74BsCvyIs9Vj4cYbA',
#    u'types': [u'restaurant', u'food', u'point_of_interest', u'establishment']},
#   {u'formatted_address': u'10 Bligh St, Sydney NSW 2000, Australia',
#    u'geometry': {u'location': {u'lat': -33.8660068, u'lng': 151.2101938},
#     u'viewport': {u'northeast': {u'lat': -33.8646826197085,
#       u'lng': 151.2114884302915},
#      u'southwest': {u'lat': -33.8673805802915, u'lng': 151.2087904697085}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'cb31572d38c6bfe8a80e55405998969415eafcad',
#    u'name': u'Spice Temple',
#    u'opening_hours': {u'open_now': False, u'weekday_text': []},
#    u'photos': [{u'height': 1651,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/108346489878618910687/photos">Spice Temple</a>'],
#      u'photo_reference': u'CmRaAAAAn_Nkbj2OM62MIGk85gM0mvuHUJi3dIaGYKfWm1NU8uSRu-56uVYo044p4aK2oTLBVO3dPdFqz6qLUIk5k6Za3ozCSBeQHTiZe9-gqGK2Ig2-R0eMd977OUENgZ1Hc5RJEhDpatMoXimCgfsz5kpMVGP3GhTzcVi9u6w26udwbn3jXbFTd6OsqQ',
#      u'width': 1167}],
#    u'place_id': u'ChIJc6EceWquEmsRmBVAjzjXM-g',
#    u'price_level': 4,
#    u'rating': 4.2,
#    u'reference': u'CmRSAAAArPzgYVz9nDJdb1UNoMl1Z4kEe3DL8L3WOS28Q1pzQGRwq-0u9qkv1SdRBZhqOc_HwsBxBbnbQLOvGeopn5ZCsC78_Gu0AjnCij0POx4lDYdwNvtGQUpTY7gklPcr-QsqEhCpdVDj-zdA9OQ261MczKZ6GhQweOmQZSKs6seJy6tyxpHM44Cd5A',
#    u'types': [u'bar',
#     u'restaurant',
#     u'food',
#     u'point_of_interest',
#     u'establishment']},
#   {u'formatted_address': u'1 Martin Pl, Sydney NSW 2000, Australia',
#    u'geometry': {u'location': {u'lat': -33.8678863, u'lng': 151.2077362},
#     u'viewport': {u'northeast': {u'lat': -33.8663492697085,
#       u'lng': 151.2091142802915},
#      u'southwest': {u'lat': -33.8690472302915, u'lng': 151.2064163197085}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'29b2ed666be62486e1c8ee234192448a3fc3a9fe',
#    u'name': u'GPO Grand - Restaurants, Bars & Functions, Sydney',
#    u'opening_hours': {u'open_now': False, u'weekday_text': []},
#    u'photos': [{u'height': 3024,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/100223721685627403147/photos">Qamal Kosim-Satyaputra</a>'],
#      u'photo_reference': u'CmRaAAAAimkr1PZes5bkDsW5B_NiPx8Wf5h0dahbZu4MleoJIxS9i5V6-MDwFj_SKOpbOhPBSyBCUdWsMBFIVpjV6tm_p4Bcs47lWQlpWl9GAnCNaKI2toxfLPWUH6pIbrmOqDdtEhCpZ8ffeh1avY2NQY6bOl8iGhTN6ZJW8e7z3hJx_vQD9A_b_SWB6A',
#      u'width': 3024}],
#    u'place_id': u'ChIJW9L-1WeuEmsRecvA53RRSos',
#    u'price_level': 2,
#    u'rating': 4.1,
#    u'reference': u'CmRSAAAAuTh8h6_d5UoSHkrcCwDK-7CCwNP03y_Wf5Jpfihqyq8t9Z2H_zMjI_iVvJulUzXxWEOHZuJHfBhurgTIqFvKec9JNhA6lXipJfmfKEftPUVnkQVmQISJ8QNYmLD_9PX7EhBleplYeHn6QbQN3OfLQGOOGhThIWUffesJsAyF-CQpPtvD__NjOA',
#    u'types': [u'restaurant',
#     u'cafe',
#     u'bar',
#     u'night_club',
#     u'food',
#     u'store',
#     u'point_of_interest',
#     u'establishment']}],
#  u'status': u'OK'}

# %%
with open('cities.txt','r') as f:
    data = f.read()

# %%
data.split('\n')
# Out:
# ['Chongqing   China',
#  'Shanghai    China',
#  'Delhi   India',
#  'Beijing China',
#  'Mumbai  India',
#  'Lagos   Nigeria',
#  'Karachi Pakistan',
#  'Dhaka   Bangladesh',
#  'Guangzhou   China',
#  'Istanbul    Turkey',
#  'Tokyo   Japan',
#  'Bengaluru   India',
#  'Moscow  Russia',
#  'S\xc3\xa3o Paulo   Brazil',
#  'Lahore  Pakistan',
#  'Cairo   Egypt',
#  'Kinshasa    DR Congo',
#  'Jakarta Indonesia',
#  'Seoul   Korea, South',
#  'Wenzhou China',
#  'Mexico City Mexico',
#  'Lima    Peru',
#  'London  United Kingdom',
#  "Xi'an   China",
#  'Hyderabad   India',
#  'Chennai India',
#  'New York City   United States',
#  'Shenzhen    China',
#  'Bangkok Thailand',
#  'Suzhou  China',
#  'Nanjing China',
#  'Dongguan    China',
#  'Tehran  Iran',
#  'Quanzhou    China',
#  'Shenyang    China',
#  'Bogot\xc3\xa1  Colombia',
#  'Ho Chi Minh City    Vietnam',
#  'Hong Kong   China',
#  'Baghdad Iraq',
#  'Fuzhou  China',
#  'Changsha    China',
#  'Wuhan   China',
#  'Tianjin China',
#  'Hanoi   Vietnam',
#  'Rio de Janeiro  Brazil',
#  'Qingdao China',
#  'Foshan  China',
#  'Zunyi   China',
#  'Santiago    Chile',
#  'Riyadh  Saudi Arabia',
#  'Ahmedabad   India',
#  'Singapore   Singapore',
#  'Shantou China',
#  'Ankara  Turkey',
#  'Yangon  Myanmar',
#  'Saint Petersburg    Russia',
#  'Casablanca  Morocco',
#  'Abidjan Ivory Coast',
#  'Chengdu China',
#  'Alexandria  Egypt',
#  'Kolkata India',
#  'Surat   India',
#  'Johannesburg    South Africa',
#  'Dar es Salaam   Tanzania',
#  'Shijiazhuang    China',
#  'Harbin  China',
#  'Giza    Egypt',
#  '\xc4\xb0zmir   Turkey',
#  'Zhengzhou   China',
#  'New Taipei City Taiwan',
#  'Los Angeles United States',
#  'Changchun   China',
#  'Cape Town   South Africa',
#  'Yokohama    Japan',
#  'Khartoum    Sudan',
#  'Guayaquil   Ecuador',
#  'Hangzhou    China',
#  'Xiamen  China',
#  'Berlin  Germany',
#  'Busan   Korea, South',
#  'Ningbo  China',
#  'Jeddah  Saudi Arabia',
#  'Durban  South Africa',
#  'Algiers Algeria',
#  'Kabul   Afghanistan',
#  'Hefei   China',
#  'Mashhad Iran',
#  'Pyongyang   Korea, North',
#  'Madrid  Spain',
#  'Faisalabad  Pakistan',
#  'Baku    Azerbaijan',
#  'Tangshan    China',
#  'Ekurhuleni Metropolitan Municipality    South Africa',
#  'Nairobi Kenya',
#  'Zhongshan   China',
#  'Pune    India',
#  'Addis Ababa Ethiopia',
#  'Jaipur  India',
#  'Buenos Aires    Argentina',
#  'Incheon Korea, South',
#  'Quezon City Philippines',
#  'Kiev    Ukraine',
#  'Salvador, Bahia Brazil',
#  'Rome    Italy',
#  'Dubai   United Arab Emirates',
#  'Luanda  Angola',
#  'Lucknow India',
#  'Kaohsiung   Taiwan',
#  'Kanpur  India',
#  'Surabaya    Indonesia',
#  'Taichung    Taiwan',
#  'Basra   Iraq',
#  'Toronto Canada',
#  'Taipei  Taiwan',
#  'Chicago United States',
#  'Osaka   Japan',
#  'Quito   Ecuador',
#  'Chaozhou    China',
#  'Fortaleza   Brazil',
#  'Chittagong  Bangladesh',
#  'Bandung Indonesia',
#  'Managua Nicaragua',
#  'Bras\xc3\xadlia    Brazil',
#  'Belo Horizonte  Brazil',
#  'Daegu   Korea, South',
#  'Houston United States',
#  'Douala  Cameroon',
#  'Medellin    Colombia',
#  'Yaound\xc3\xa9 Cameroon',
#  'Nagpur  India',
#  'Cali    Colombia',
#  'Tashkent    Uzbekistan',
#  'Nagoya  Japan',
#  'Isfahan Iran',
#  'Phnom Penh  Cambodia',
#  'Kochi   India',
#  'Paris   France',
#  'Ouagadougou Burkina Faso',
#  'Lanzhou China',
#  'Kano    Nigeria',
#  'Dalian  China',
#  'Guatemala City  Guatemala',
#  'Havana  Cuba',
#  'Rawalpindi  Pakistan',
#  'Medan   Indonesia',
#  'Accra   Ghana',
#  'Visakhapatnam   India',
#  'Gujranwala  Pakistan',
#  'Jinan   China',
#  'Karaj   Iran',
#  'Peshawar    Pakistan',
#  'Minsk   Belarus',
#  'Caracas Venezuela',
#  "Sana'a  Yemen",
#  'Sapporo Japan',
#  'Tainan  Taiwan',
#  'Bucharest   Romania',
#  'Curitiba    Brazil',
#  'Shiraz  Iran',
#  'Vienna  Austria',
#  'Brazzaville Congo Republic',
#  'Bhopal  India',
#  'Hamburg Germany',
#  'Manila  Philippines',
#  'Kuala Lumpur    Malaysia',
#  'Maputo  Mozambique',
#  'Budapest    Hungary',
#  'Warsaw  Poland',
#  'Lusaka  Zambia',
#  'Kathmandu   Nepal',
#  'Tabriz  Iran',
#  'Hyderabad, Sindh    Pakistan',
#  'Palembang   Indonesia',
#  'Almaty  Kazakhstan',
#  'Tijuana Mexico',
#  'Patna   India',
#  'Montreal    Canada',
#  'Davao City  Philippines',
#  'Harare  Zimbabwe',
#  'Barcelona   Spain',
#  'Maracaibo   Venezuela',
#  'Caloocan    Philippines',
#  'Philadelphia    United States',
#  'Novosibirsk Russia',
#  'Phoenix, Arizona    United States',
#  'Bulawayo    Zimbabwe',
#  'Oran    Algeria',
#  'Semarang    Indonesia',
#  'Recife  Brazil',
#  'Kobe    Japan',
#  'Daejeon Korea, South',
#  'Kampala Uganda',
#  'Kawasaki, Kanagawa  Japan',
#  'Guadalajara Mexico',
#  'Auckland    New Zealand',
#  'Vijayawada  India',
#  'Fukuoka Japan',
#  'Kwangju Korea, South',
#  'Porto Alegre    Brazil',
#  'Kyoto   Japan',
#  'San Antonio United States',
#  'Santa Cruz de la Sierra Bolivia',
#  'Munich  Germany',
#  'Kharkiv Ukraine',
#  'Yekaterinburg   Russia',
#  'San Diego   United States',
#  'Barranquilla    Colombia',
#  'Milan   Italy',
#  'Ibadan  Nigeria',
#  'Makassar    Indonesia',
#  'C\xc3\xb3rdoba  Argentina',
#  'Prague  Czech Republic',
#  'Mandalay    Myanmar',
#  'Dallas  United States',
#  'Montevideo  Uruguay',
#  'Nizhny Novgorod Russia',
#  'Abuja   Nigeria',
#  'Calgary Canada',
#  'Saitama, Saitama    Japan',
#  'Hiroshima   Japan',
#  'Rosario, Santa Fe   Argentina',
#  'Brisbane    Australia',
#  'Belgrade    Serbia',
#  'Campinas    Brazil',
#  'Ulsan   Korea, South',
#  'Omsk    Russia',
#  'Dakar   Senegal',
#  'Abu Dhabi   United Arab Emirates',
#  'Monterrey   Mexico',
#  'Tripoli Libya',
#  'Rostov-on-Don   Russia',
#  "T'bilisi    Georgia",
#  'Fez, Morocco    Morocco',
#  'Birmingham  United Kingdom',
#  'Yerevan Armenia',
#  'Cologne Germany',
#  'Tunis   Tunisia',
#  'Islamabad   Pakistan',
#  '']
